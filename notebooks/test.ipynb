# %%
import pandas as pd

# %%
expr = pd.read_csv("/Users/tusharsingh/Downloads/luad_tcga_gdc/data_mrna_seq_read_counts.txt" , sep='\t', index_col=0)
expr
# Out:
#                 TCGA-05-4244-01A  TCGA-05-4249-01A  TCGA-05-4250-01A  \
# Entrez_Gene_Id
# 1                              7                13                 7
# 10                            10                11                 5
# 100                          503               250               835
# 1000                          18                28               247
# 10000                       3437               746              2751
# ...                          ...               ...               ...
# 9992                           0                 1                 0
# 9993                        6334             14204              6991
# 9994                        1338              1174               816
# 9995                           0                 0                 0
# 9997                          42                31                14
#
#                 TCGA-05-4382-01A  TCGA-05-4384-01A  TCGA-05-4389-01A  \
# Entrez_Gene_Id
# ...

# %%
# Out:
#                 TCGA-05-4244-01A  TCGA-05-4249-01A  TCGA-05-4250-01A  \
# Entrez_Gene_Id
# 1                         0.0295            0.0508            0.0291
# 10                        0.1313            0.1338            0.0646
# 100                       3.0209            1.3910            4.9337
# 1000                      0.0354            0.0510            0.4776
# 10000                     4.5403            0.9130            3.5752
# ...                          ...               ...               ...
# 9992                      0.0000            0.0147            0.0000
# 9993                     19.0646           39.6086           20.7015
# 9994                      2.7707            2.2523            1.6624
# 9995                      0.0000            0.0000            0.0000
# 9997                      0.5131            0.3509            0.1683
#
#                 TCGA-05-4382-01A  TCGA-05-4384-01A  TCGA-05-4389-01A  \
# Entrez_Gene_Id
# ...
